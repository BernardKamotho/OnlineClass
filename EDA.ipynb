# %%
import pandas
# EDA = Exploratory Data Analysis
data = pandas.read_csv("datasets/supermarket_data.csv")
data

# quantitative ~ quantity
# Qualitative ~ Categorical
# Below is the dataframe for ourdata
# Out:
#        Invoice ID     city customertype  gender                 product  \
# 0     750-67-8428  Nairobi       Member  Female       Health and beauty
# 1     226-31-3081   Nakuru       Normal  Female  Electronic accessories
# 2     631-41-3108  Nairobi       Normal  Female      Home and lifestyle
# 3     123-19-1176  Nairobi       Member  Female       Health and beauty
# 4     373-73-7910  Nairobi       Normal  Female       Health and beauty
# ...           ...      ...          ...     ...                     ...
# 996   233-67-5758   Nakuru       Normal    Male       Health and beauty
# 997   303-96-2227  Mombasa       Normal  Female      Home and lifestyle
# 998   727-02-1313  Nairobi       Member    Male      Food and beverages
# 999   347-56-2442  Nairobi       Normal    Male      Home and lifestyle
# 1000  849-09-3807  Nairobi       Member  Female     Fashion accessories
#
#       itemprice  quantity      total       date   time      payment  \
# ...

# %%
data.describe()
# Out:
#         itemprice     quantity        total  customersalary       rating
# count  998.000000  1001.000000  1001.000000     1001.000000  1001.000000
# mean    55.686523     5.505495   322.739927       15.368568     6.972527
# std     26.538665     2.925444   245.867115       11.707958     1.717729
# min     10.080000     1.000000    10.678500        0.508500     4.000000
# 25%     32.825000     3.000000   122.524500        5.834500     5.500000
# 50%     55.230000     5.000000   253.680000       12.080000     7.000000
# 75%     78.040000     8.000000   471.030000       22.430000     8.500000
# max     99.960000    10.000000  1042.650000       49.650000    10.000000

# %%
# print out one single column
data["city"]
# Out:
# 0       Nairobi
# 1        Nakuru
# 2       Nairobi
# 3       Nairobi
# 4       Nairobi
#          ...
# 996      Nakuru
# 997     Mombasa
# 998     Nairobi
# 999     Nairobi
# 1000    Nairobi
# Name: city, Length: 1001, dtype: object

# %%
# Chack the number of males vs female
data.groupby(["city", "gender", "payment"]).size()
# Out:
# city     gender  payment
# Mombasa  Female  Cash            41
#                  Credit card     58
#                  MPESA           93
#          Male    Cash            32
#                  Credit card     25
#                  MPESA           51
# Nairobi  Female  Cash            66
#                  Credit card     57
#                  MPESA          107
#          Male    Cash            52
#                  Credit card     41
#                  MPESA           72
# Nakuru   Female  Cash            52
#                  Credit card     56
#                  MPESA           95
#          Male    Cash            32
#                  Credit card     18
#                  MPESA           53
# dtype: int64

# %%
data.groupby("gender").size()
# Out:
# gender
# Female    625
# Male      376
# dtype: int64

# %%
# plotting graphs based on the data we have
import seaborn as sns
import matplotlib.pyplot as plt

# create a count plot graph
sns.countplot(x="gender", data=data, palette='autumn')
# Out:
# C:\Users\Ben\AppData\Local\Temp\ipykernel_11532\206906077.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="gender", data=data, palette='autumn')
# <Axes: xlabel='gender', ylabel='count'>

# %%
# Chack the number of males vs female
data.groupby(["city", "gender"]).size()
# Out:
# city     gender
# Mombasa  Female    192
#          Male      108
# Nairobi  Female    230
#          Male      165
# Nakuru   Female    203
#          Male      103
# dtype: int64

# %%
# create a count plot graph
sns.countplot(x="gender", data=data, palette='spring', hue='city')
plt.title("Distribution of males to females in cities")
plt.xlabel("Gender Distribution")
plt.ylabel("Total number of persons")
# Out:
# Text(0, 0.5, 'Total number of persons')

# %%
# creating a barplot
sns.barplot(x='gender', y='total', data=data, palette='autumn', hue='city')
plt.title("Gender against Total number")
plt.xlabel("Gender Dist")
plt.ylabel("Total Number of persons")
# Out:
# Text(0, 0.5, 'Total Number of persons')

# %%
# Below is a line graph
import matplotlib.dates as mdates

# format the axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b')) # jan feb etc
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

# create the line graph
sns.lineplot(x='date', y='total', data=data)
# Out:
# <Axes: xlabel='date', ylabel='total'>

# %%
# below is a piechart
data['payment'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#coming up with pie charts  
#import the libraries 
import pandas as pd
import matplotlib.pyplot as plt
#load your data set
data = pd.read_csv("datasets/supermarket_data.csv")
# Step 1: Count the number of occurrences for each gender
gender_counts = data['payment'].value_counts()
# Step 2: Create the pie chart
plt.pie(
    gender_counts,                  # Values
    labels=gender_counts.index,     # Labels (Male, Female)
    autopct='%1.1f%%',              # Show percentages
    startangle=140,                 # Rotate for better layout
    shadow=True,                    # Add shadow for 3D effect
    colors = ['#00B8A9', '#F6416C', '#FFDE7D', '#FF9A76', '#6A0572', '#AB83A1']
  # Optional: Custom colors
)
# Step 3: Make it circular and add title
plt.axis('equal')
plt.title('Payment Method')
plt.show()

# %%
# Below is a swarmplot
sns.swarmplot(x='gender', y="total", data=data, palette='winter', hue="payment")
# Out:
# <Axes: xlabel='gender', ylabel='total'>

# %%
# below is a scatter plot
sns.scatterplot(x='rating', y="total", data=data, palette="spring", hue="gender")
# Out:
# <Axes: xlabel='rating', ylabel='total'>
